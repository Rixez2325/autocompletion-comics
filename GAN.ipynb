# %%
# To generate GIFs
#!pip install imageio
#!pip install git+https://github.com/tensorflow/docs
#!pip install tensorflow

# %% [markdown]
# # Imports

# %%
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import tensorflow as tf
import time

from IPython import display

from tqdm import tqdm

# %% [markdown]
# ---------

# %% [markdown]
# # Datasets

# %%
(train_images, train_labels), (_, _) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
train_images = (train_images - 127.5) / 127.5  # Normalize the images to [-1, 1]

# %%
BUFFER_SIZE = 60000
BATCH_SIZE = 256

# %%
# Batch and shuffle the data
train_dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# ------

# %% [markdown]
# # Model GAN

# %% [markdown]
# ## Generator

# %%
def make_generator_model():
    model = tf.keras.Sequential()
    model.add(layers.Dense(7*7*256, use_bias=False, input_shape=(100,)))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    assert model.output_shape == (None, 7, 7, 256)  # Note: None is the batch size

    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    assert model.output_shape == (None, 7, 7, 128)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    assert model.output_shape == (None, 14, 14, 64)
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))
    assert model.output_shape == (None, 28, 28, 1)

    return model

# %%
generator = make_generator_model()

noise = tf.random.normal([1, 100])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0], cmap='gray')

# %% [markdown]
# ## Discriminator

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same',
                                     input_shape=[28, 28, 1]))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1))

    return model

# %%
discriminator = make_discriminator_model()
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.0008793]], shape=(1, 1), dtype=float32)

# %% [markdown]
# ------

# %% [markdown]
# ## Loss and optimizers

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %% [markdown]
# ### Discriminator loss

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

# %% [markdown]
# ### Generator loss

# %%
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %% [markdown]
# ### Optimizers

# %%
generator_optimizer = tf.keras.optimizers.Adam(1e-4)
discriminator_optimizer = tf.keras.optimizers.Adam(1e-4)

# %% [markdown]
# ----

# %% [markdown]
# # Save checkpoint

# %%
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %% [markdown]
# -----

# %% [markdown]
# # Training loop

# %%
EPOCHS = 50
noise_dim = 100
num_examples_to_generate = 16

# You will reuse this seed overtime (so it's easier)
# to visualize progress in the animated GIF)
seed = tf.random.normal([num_examples_to_generate, noise_dim])

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, noise_dim])

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
      generated_images = generator(noise, training=True)

      real_output = discriminator(images, training=True)
      fake_output = discriminator(generated_images, training=True)

      gen_loss = generator_loss(fake_output)
      disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

# %% [markdown]
# ## Generate and save image

# %%
def generate_and_save_images(model, epoch, test_input):
  # Notice `training` is set to False.
  # This is so all layers run in inference mode (batchnorm).
  predictions = model(test_input, training=False)

  fig = plt.figure(figsize=(4, 4))

  for i in tqdm(range(predictions.shape[0])):
      plt.subplot(4, 4, i+1)
      plt.imshow(predictions[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
      plt.axis('off')

  plt.savefig('image_at_epoch_{:04d}.png'.format(epoch))
  plt.show()

# %%
def train(dataset, epochs):
  for epoch in tqdm(range(epochs)):
    start = time.time()

    for image_batch in tqdm(dataset):
      train_step(image_batch)

    # Produce images for the GIF as you go
    display.clear_output(wait=True)
    generate_and_save_images(generator,
                             epoch + 1,
                             seed)

    # Save the model every 15 epochs
    if (epoch + 1) % 15 == 0:
      checkpoint.save(file_prefix = checkpoint_prefix)

    print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))

  # Generate after the final epoch
  display.clear_output(wait=True)
  generate_and_save_images(generator,
                           epochs,
                           seed)

# %% [markdown]
# # Train the model

# %%
train(train_dataset, EPOCHS)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#  50%|█████     | 8/16 [00:00<00:00, 75.04it/s]
# 100%|██████████| 16/16 [00:00<00:00, 76.42it/s]
#  28%|██▊       | 14/50 [1:16:47<3:17:27, 329.09s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 train(train_dataset, EPOCHS)
#
# Cell In[35], line 16, in train(dataset, epochs)
#      14   # Save the model every 15 epochs
#      15   if (epoch + 1) % 15 == 0:
# ---> 16     checkpoint.save(file_prefix = checkpoint_prefix)
#      18   print ('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))
#      20 # Generate after the final epoch
#
# File ~\PycharmProjects\manga_scrapper\venv\Lib\site-packages\tensorflow\python\checkpoint\checkpoint.py:2409, in Checkpoint.save(self, file_prefix, options)
#    2406 else:
#    2407   checkpoint_number = assign_op.numpy()
# -> 2409 return self._write(
#    2410     "%s-%d" % (file_prefix, checkpoint_number),
#    2411     options=options,
#    2412     write_done_callback=_update_checkpoint_state_internal)
#
# File ~\PycharmProjects\manga_scrapper\venv\Lib\site-packages\tensorflow\python\checkpoint\checkpoint.py:2291, in Checkpoint._write(self, file_prefix, options, write_done_callback)
#    2289 start_time = time.time()
#    2290 options = options or checkpoint_options.CheckpointOptions()
# -> 2291 output = self._saver.save(file_prefix=file_prefix, options=options)
#    2292 output = _convert_file_name_tensor_to_string(output)
#    2294 if write_done_callback:
#
# File ~\PycharmProjects\manga_scrapper\venv\Lib\site-packages\tensorflow\python\checkpoint\checkpoint.py:1304, in TrackableSaver.save(self, file_prefix, checkpoint_number, session, options)
#    1301 if not tensor_util.is_tensor(file_prefix):
#    1302   file_io.recursive_create_dir(os.path.dirname(file_prefix))
# -> 1304 save_path, new_feed_additions = self._save_cached_when_graph_building(
#    1305     file_prefix_tensor, object_graph_tensor, options)
#    1307 if new_feed_additions:
#    1308   feed_dict.update(new_feed_additions)
#
# File ~\PycharmProjects\manga_scrapper\venv\Lib\site-packages\tensorflow\python\checkpoint\checkpoint.py:1232, in TrackableSaver._save_cached_when_graph_building(self, file_prefix, object_graph_tensor, options)
#    1215 def _save_cached_when_graph_building(self, file_prefix, object_graph_tensor,
#    1216                                      options):
#    1217   """Create or retrieve save ops.
#    1218
#    1219   Args:
#    (...)
#    1229     checkpoint. When executing eagerly only the first argument is meaningful.
#    1230   """
#    1231   serialized_tensors, feed_additions, registered_savers, graph_proto = (
# -> 1232       self._gather_serialized_tensors(object_graph_tensor))
#    1234   if (self._last_save_object_graph != graph_proto
#    1235       # When executing eagerly, we need to re-create SaveableObjects each
#    1236       # time save() is called so they pick up new Tensors passed to their
#    1237       # constructors. That means the Saver needs to be copied with a new
#    1238       # var_list.
#    1239       or context.executing_eagerly() or ops.inside_function()):
#    1240     saver = functional_saver.MultiDeviceSaver(serialized_tensors,
#    1241                                               registered_savers)
#
# File ~\PycharmProjects\manga_scrapper\venv\Lib\site-packages\tensorflow\python\checkpoint\checkpoint.py:1193, in TrackableSaver._gather_serialized_tensors(self, object_graph_tensor)
#    1190 def _gather_serialized_tensors(self, object_graph_tensor=None):
#    1191   """Gathers tensors to save to ckpt and includes the object graph proto."""
#    1192   serialized_tensors, feed_additions, registered_savers, graph_proto = (
# -> 1193       save_util.serialize_graph_view(self._graph_view,
#    1194                                      self._object_map,
#    1195                                      cache=self._cache))
#    1197   if self._saveables_cache is not None:
#    1198     # Store saveables cache for restoration purposes.
#    1199     self._saveables_cache = (
#    1200         saveable_object_util.serialized_tensors_to_saveable_cache(
#    1201             serialized_tensors))
#
# File ~\PycharmProjects\manga_scrapper\venv\Lib\site-packages\tensorflow\python\checkpoint\save_util.py:309, in serialize_graph_view(graph_view, object_map, call_with_mapped_captures, cache)
#     304 tensor_trackables, pystate_trackables, registered_trackables = (
#     305     _split_trackables(trackable_data))
#     307 object_graph_proto = _fill_object_graph_proto(trackable_data)
# --> 309 serialized_tensors = _get_and_write_tensors_to_serialize(
#     310     tensor_trackables,
#     311     node_ids,
#     312     call_with_mapped_captures,
#     313     cache,
#     314     object_graph_proto)
#     315 registered_savers = _get_and_write_registered_savers(
#     316     registered_trackables, object_graph_proto)
#     318 # PythonState trackables must be treated differently depending on if the
#     319 # checkpoint is being saved in TF1 graph mode (`cache` exists) or
#     320 # eager mode (`cache` is None).
#
# File ~\PycharmProjects\manga_scrapper\venv\Lib\site-packages\tensorflow\python\checkpoint\save_util.py:152, in _get_and_write_tensors_to_serialize(tensor_trackables, node_ids, call_with_mapped_captures, cache, object_graph_proto)
#     148   continue
#     150 legacy_name = saveable_compat.get_saveable_name(td.object_to_save) or ""
# --> 152 if (not saveable_object_util.trackable_has_serialize_to_tensor(
#     153     td.object_to_save) or
#     154     legacy_name):
#     155   # Use the legacy code path for objects that are using SaveableObjects
#     156   # or the compat saveable name decorator.
#     157   trackable, tensor_dict = _get_tensors_from_legacy_saveable(
#     158       td, node_ids, call_with_mapped_captures, object_graph_proto)
#     159 else:
#
# File ~\PycharmProjects\manga_scrapper\venv\Lib\site-packages\tensorflow\python\training\saving\saveable_object_util.py:745, in trackable_has_serialize_to_tensor(obj)
#     743 """Returns whether obj's class has `_serialize_to_tensors` defined."""
#     744 try:
# --> 745   if "_serialize_to_tensors" in obj.__dict__:
#     746     # In some cases (e.g. restored objects), the object may have
#     747     # `_serialize_to_tensors` even if the class does not.
#     748     return True
#     749 except AttributeError:  # Data structure proxy wrappers don't have __dict__.
#
# File ~\PycharmProjects\manga_scrapper\venv\Lib\site-packages\tensorflow\python\trackable\data_structures.py:823, in _DictWrapper.__getattribute__(self, name)
#     821   return object.__getattribute__(self, name)
#     822 else:
# --> 823   return super().__getattribute__(name)
#
# TypeError: this __dict__ descriptor does not support '_DictWrapper' objects

# %% [markdown]
# # Restore the lastest checkpoint

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %% [markdown]
# # Create GIF

# %%
# Display a single image using the epoch number
def display_image(epoch_no):
  return PIL.Image.open('image_at_epoch_{:04d}.png'.format(epoch_no))

# %%
display_image(15)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x400>

# %%
import imageio.v2 as imageio
anim_file = 'dcgan.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('image*.png')
  filenames = sorted(filenames)
  for filename in filenames:
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)
